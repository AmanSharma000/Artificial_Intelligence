# %%
import numpy as np
import pandas as pd
import time

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC, SVC
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
df=pd.read_csv(r"C:\Users\91861\Desktop\Artifical Intelligence\Machine Leraning\10. SVM\Churn_Modelling.csv")

# %%
# Drop ID-like columns
df = df.drop(columns=["RowNumber", "CustomerId", "Surname"])

# Target
y = df["Exited"].values
X = df.drop(columns=["Exited"])

# One-hot encode categoricals
X = pd.get_dummies(
    X,
    columns=["Geography", "Gender"],
    drop_first=True
)

# Convert labels {0,1} → {-1,+1}
y = np.where(y == 0, -1, 1)

# %%
X.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0               1        101348.88              False            False
# 1               1        112542.58              False             True
# 2               0        113931.57              False            False
# 3               0         93826.63              False            False
# 4               1         79084.10              False             True
#
#    Gender_Male
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
y
# Out:
# array([ 1, -1,  1, ...,  1,  1, -1])

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X.values, y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

# Standardize
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %%
start = time.time()
lin_svm = LinearSVC(max_iter=5000)
lin_svm.fit(X_train, y_train)
svm_lin_time = time.time() - start
y_pred_lin_svm=lin_svm.predict(X_test)
acc_svm_lin = accuracy_score(y_test, lin_svm.predict(X_test))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
svm_lin_time
# Out:
# 0.3135838508605957

# %%
acc_svm_lin
# Out:
# 0.8104

# %%
confusion_matrix(y_test,y_pred_lin_svm)
# Out:
# array([[1953,   38],
#        [ 436,   73]], dtype=int64)

# %%
#------------------------------------------------------

# %%
start = time.time()
linear_svm = SVC(kernel="linear")
linear_svm.fit(X_train, y_train)
svm_linear_time = time.time() - start
y_pred_linear_svm=linear_svm.predict(X_test)
acc_svm_linear = accuracy_score(y_test, linear_svm.predict(X_test))

# %%
svm_linear_time
# Out:
# 1.6298942565917969

# %%
acc_svm_linear
# Out:
# 0.7964

# %%
confusion_matrix(y_test,y_pred_linear_svm)
# Out:
# array([[1991,    0],
#        [ 509,    0]], dtype=int64)

# %%
#----------------------------------------------------

# %%
start = time.time()
rbf_svm = SVC(kernel="rbf", gamma="scale")
rbf_svm.fit(X_train, y_train)
svm_rbf_time = time.time() - start
y_pred_rbf_svm=rbf_svm.predict(X_test)
acc_svm_rbf = accuracy_score(y_test, rbf_svm.predict(X_test))

# %%
svm_rbf_time
# Out:
# 1.7350425720214844

# %%
acc_svm_rbf
# Out:
# 0.8624

# %%
confusion_matrix(y_test,y_pred_rbf_svm)
# Out:
# array([[1953,   38],
#        [ 306,  203]], dtype=int64)

# %%
#--------------------------------------------------

# %%
start = time.time()
poly_svm = SVC(kernel="poly", gamma="scale")
poly_svm.fit(X_train, y_train)
svm_poly_time = time.time() - start
y_pred_poly_svm=poly_svm.predict(X_test)
acc_svm_poly = accuracy_score(y_test, poly_svm.predict(X_test))

# %%
svm_poly_time
# Out:
# 1.8645727634429932

# %%
acc_svm_poly
# Out:
# 0.8576

# %%
confusion_matrix(y_test,y_pred_poly_svm)
# Out:
# array([[1962,   29],
#        [ 327,  182]], dtype=int64)
