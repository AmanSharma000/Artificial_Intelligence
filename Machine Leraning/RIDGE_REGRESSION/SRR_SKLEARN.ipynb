# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
df=pd.read_csv(r"C:\Users\91861\Desktop\Artifical Intelligence\Machine Leraning\RIDGE_REGRESSION\tv_sales.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.head()
# Out:
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
plt.scatter(df['TV'],df['Sales'])
plt.xlabel('TV:spent amount')
plt.ylabel('Sales:resulting sales volume')
# Out:
# Text(0, 0.5, 'Sales:resulting sales volume')

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
print(x.shape,y.shape)
# Out:
# (200, 1) (200,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (160, 1) (40, 1) (160,) (40,)

# %%
ridge=Ridge(alpha=500000)

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=500000)

# %%
y_pred=ridge.predict(x_test)

# %%
print("MAE :",mean_absolute_error(y_test,y_pred))
print("MSE :",mean_squared_error(y_test,y_pred))
print("r2_score :",r2_score(y_test,y_pred))
# Out:
# MAE : 3.0221758633240285
# MSE : 13.876615523674204
# r2_score : 0.25299935173683585

# %%
ridge.coef_
# Out:
# array([0.03674524])

# %%
ridge.intercept_
# Out:
# 8.843274920944467

# %%
plt.scatter(df['TV'],df['Sales'])
plt.plot(x_train,ridge.predict(x_train),color='red')
plt.xlabel('TV:spent amount')
plt.ylabel('Sales:resulting sales volume')
# Out:
# Text(0, 0.5, 'Sales:resulting sales volume')
