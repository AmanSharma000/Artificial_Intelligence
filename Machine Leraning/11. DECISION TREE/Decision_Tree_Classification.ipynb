# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris

# %%
iris = load_iris()
df = pd.DataFrame(iris.data)

# %%
df.columns = iris.feature_names
df['class'] = iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
X=df.iloc[:,0:4]
y=df.iloc[:,4]

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: class, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2,random_state=22,satify=)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from sklearn.tree import plot_tree

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 80,50

plot_tree(clf)
# Out:
# [Text(0.3333333333333333, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.665\nsamples = 120\nvalue = [42, 36, 42]'),
#  Text(0.2222222222222222, 0.75, 'gini = 0.0\nsamples = 42\nvalue = [42, 0, 0]'),
#  Text(0.4444444444444444, 0.75, 'x[2] <= 4.75\ngini = 0.497\nsamples = 78\nvalue = [0, 36, 42]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 33\nvalue = [0, 33, 0]'),
#  Text(0.5555555555555556, 0.5833333333333334, 'x[3] <= 1.75\ngini = 0.124\nsamples = 45\nvalue = [0, 3, 42]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'x[2] <= 5.3\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 3]'),
#  Text(0.2222222222222222, 0.25, 'x[0] <= 6.15\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.1111111111111111, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3333333333333333, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.4444444444444444, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.7777777777777778, 0.4166666666666667, 'x[2] <= 4.85\ngini = 0.049\nsamples = 40\nvalue = [0, 1, 39]'),
#  Text(0.6666666666666666, 0.25, 'x[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5555555555555556, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7777777777777778, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8888888888888888, 0.25, 'gini = 0.0\nsamples = 37\nvalue = [0, 0, 37]')]
