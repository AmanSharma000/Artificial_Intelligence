# %%
import pickle

with open('MLR_USING_PIPE.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
import pandas as pd

sample = pd.DataFrame([{
    'YearsExperience': 5,
    'Age': 30,
    'Education': 'Bachelor',
    'JobType': 'Engineering',
    'Location': 'Urban',
    'CompanySize': 'Medium',
    'PerformanceRating': 3,
    'ProjectsCompleted': 10,
    'Certifications': 2,
    'Promoted': 'No'
}])

model.predict(sample)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65549.827339])
