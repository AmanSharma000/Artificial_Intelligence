# %%
import numpy as np

# %%
zero_d = np.array(3)

# %%
zero_d
# Out:
# array(3)

# %%
zero_d.ndim
# Out:
# 0

# %%
zero_d.shape
# Out:
# ()

# %%
zero_d.size
# Out:
# 1

# %%
one_d = np.array([1,2,6,7])

# %%
one_d
# Out:
# array([1, 2, 6, 7])

# %%
one_d.ndim
# Out:
# 1

# %%
one_d.shape
# Out:
# (4,)

# %%
one_d.size
# Out:
# 4

# %%
two_d = np.array([[1,2,6,7],[6,8,7,9]])

# %%
two_d
# Out:
# array([[1, 2, 6, 7],
#        [6, 8, 7, 9]])

# %%
two_d.ndim
# Out:
# 2

# %%
two_d.shape
# Out:
# (2, 4)

# %%
two_d.size
# Out:
# 8

# %%
three_d = np.array([[[1,2,6,7],[6,8,7,9]],[[8,9,5,4],[5,5,5,5]],[[9,9,9,9],[6,8,7,9]],[[1,2,6,7],[6,8,7,9]]])

# %%
three_d
# Out:
# array([[[1, 2, 6, 7],
#         [6, 8, 7, 9]],
#
#        [[8, 9, 5, 4],
#         [5, 5, 5, 5]],
#
#        [[9, 9, 9, 9],
#         [6, 8, 7, 9]],
#
#        [[1, 2, 6, 7],
#         [6, 8, 7, 9]]])

# %%
three_d.ndim
# Out:
# 3

# %%
three_d.shape
# Out:
# (4, 2, 4)

# %%
three_d.size
# Out:
# 32

# %%
four_d=np.array([[[[1,2,6,7],[6,8,7,9]],[[8,9,5,4],[5,5,5,5]],[[9,9,9,9],[6,8,7,9]]],[[[1,2,6,7],[1,8,4,9]],[[8,9,5,4],[5,5,5,5]],[[1,1,1,1],[6,8,7,9]]]])

# %%
four_d.ndim
# Out:
# 4

# %%
four_d.shape
# Out:
# (2, 3, 2, 4)

# %%
four_d.size
# Out:
# 48
